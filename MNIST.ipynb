# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from tensorflow.keras.datasets.mnist import load_data
(X_train,Y_train),(X_test,Y_test)=load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 7s 1us/step

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %%
import numpy as np

for i in range(10):
    x=np.random.randint(60000)
    plt.matshow(X_train[x])

# %%
X_train=X_train/255
X_test=X_test/255

# %%
X_train_flat=X_train.reshape(len(X_train),28*28)
X_test_flat=X_test.reshape(len(X_test),28*28)

# %%
model=tf.keras.Sequential()
model.add(tf.keras.layers.Dense(100,input_shape=(784,)))
model.add(tf.keras.layers.Dense(100,activation='relu'))
model.add(tf.keras.layers.Dense(10,activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 100)               78500
# _________________________________________________________________
# dense_4 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 89,610
# Trainable params: 89,610
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model.fit(X_train_flat,Y_train,batch_size=128,epochs=5)
# Out:
# Epoch 1/5
# 469/469 [==============================] - 1s 3ms/step - loss: 1.2326 - accuracy: 0.6296
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.5370 - accuracy: 0.8447
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.4154 - accuracy: 0.8800
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3686 - accuracy: 0.8926
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3419 - accuracy: 0.9011

# %%
model.evaluate(X_test_flat,Y_test)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 1.7271 - accuracy: 0.7275
# [1.7270586490631104, 0.7275000214576721]
